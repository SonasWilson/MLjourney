# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
df['flower'] = df.target.apply(lambda x:iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  target  flower
# 0                5.1               3.5  ...       0  setosa
# 1                4.9               3.0  ...       0  setosa
# 2                4.7               3.2  ...       0  setosa
# 3                4.6               3.1  ...       0  setosa
# 4                5.0               3.6  ...       0  setosa
#
# [5 rows x 6 columns]

# %%
len(df)
# Out:
# 150

# %%
df[df.target == 1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  ...  target      flower
# 50                7.0               3.2  ...       1  versicolor
# 51                6.4               3.2  ...       1  versicolor
# 52                6.9               3.1  ...       1  versicolor
# 53                5.5               2.3  ...       1  versicolor
# 54                6.5               2.8  ...       1  versicolor
#
# [5 rows x 6 columns]

# %%
df[df.target == 2].head()
# Out:
#      sepal length (cm)  sepal width (cm)  ...  target     flower
# 100                6.3               3.3  ...       2  virginica
# 101                5.8               2.7  ...       2  virginica
# 102                7.1               3.0  ...       2  virginica
# 103                6.3               2.9  ...       2  virginica
# 104                6.5               3.0  ...       2  virginica
#
# [5 rows x 6 columns]

# %%
df[df.target == 0].head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  target  flower
# 0                5.1               3.5  ...       0  setosa
# 1                4.9               3.0  ...       0  setosa
# 2                4.7               3.2  ...       0  setosa
# 3                4.6               3.1  ...       0  setosa
# 4                5.0               3.6  ...       0  setosa
#
# [5 rows x 6 columns]

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100:]

# %% [markdown]
# **sepal length and width**

# %%
plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'], color='green', marker='+', label='setosa')
plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'], color='blue', marker='+', label='virginica')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.legend()

# %% [markdown]
# sepal length and width

# %%
plt.scatter(df0['petal length (cm)'], df0['petal width (cm)'], color='green', marker='+', label='setosa')
plt.scatter(df1['petal length (cm)'], df1['petal width (cm)'], color='blue', marker='+', label='virginica')
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.legend()

# %% [markdown]
# **train test split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2)

# %%
len(X_train)
# Out:
# 120

# %%
len(X_test)
# Out:
# 30

# %% [markdown]
# **Create knn model**

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %%
# predicting virginica
knn.predict([[7.1,	3.0,	5.9,	2.1	]])
# Out:
# array([2])

# %% [markdown]
# **confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_test)
cm
# Out:
# array([[17,  0,  0],
#        [ 0,  6,  0],
#        [ 0,  0,  7]])

# %%
import seaborn as sn
plt.figure(figsize=(7,5))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(58.222222222222214, 0.5, 'Truth')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       1.00      0.83      0.91         6
#            2       0.88      1.00      0.93         7
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.94      0.95        30
# weighted avg       0.97      0.97      0.97        30
