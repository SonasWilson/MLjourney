# %%
from sklearn.datasets import load_iris
# %matplotlib inline
import matplotlib.pyplot as plt
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.data[0]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris.target[[10, 25, 50]]            #virginica
# Out:
# array([0, 0, 1])

# %% [markdown]
# ### Create and train model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=2000)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
model.predict(X_test)      # 0 = setosa, 1 = versicolor, 2 = virginica
# Out:
# array([2, 1, 1, 0, 0, 1, 0, 2, 2, 1, 2, 0, 0, 2, 2, 1, 1, 2, 0, 0, 0, 1,
#        2, 2, 1, 2, 0, 1, 0, 2, 2, 2, 2, 0, 0, 1, 2, 1, 1, 1, 1, 0, 2, 1,
#        0, 1, 0, 0, 2, 1, 1, 2, 0, 0, 0, 1, 0, 2, 1, 0])

# %% [markdown]
# ### Accuracy of the model

# %%
model.score(X_test,y_test)
# Out:
# 0.9833333333333333

# %% [markdown]
# ## **Confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[21,  0,  0],
#        [ 0, 19,  0],
#        [ 0,  1, 19]])

# %%
import seaborn as sn
plt.figure(figsize = (3,3))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(8.222222222222223, 0.5, 'Truth')
